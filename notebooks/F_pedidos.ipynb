# %% [markdown]
# <a href="https://colab.research.google.com/github/AristidesAntonioOrellanaZelaya/etl-data-pipeline-25-0544-2022/blob/main/notebooks/F_pedidos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/AristidesAntonioOrellanaZelaya/etl-data-pipeline-25-0544-2022/refs/heads/main/data/raw/F_pedidos.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   id_pedido id_cliente fecha_pedido    monto     estado
# 0   PED7000     CL1138   2024-11-28  1984.03   enviado
# 1   PED7001        NaN   2025-01-31  2395.24  cancelado
# 2   PED7002     CL1067   2024-07-13   433.46  cancelado
# 3   PED7003     CL1097   2025-05-02   352.01  cancelado
# 4   PED7004     CL1068   2024-12-20  1182.84    enviado

# %% [markdown]
# Limpiar Datos

# %%
df = df.drop_duplicates()
df = df.dropna()

# %% [markdown]
# Separar curated y rejects

# %%
df_rejects = df[df.isnull().any(axis=1)]
df_curated = df.dropna()
print(f"Curated: {len(df_curated)} | Rejects: {len(df_rejects)}")
# Out:
# Curated: 214 | Rejects: 0

# %% [markdown]
# Cargar a PostgreSQL

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://etl_seguros_0bu1_user:77XuQLEAFlcOXDHTkkoSKUTTmQKQe6H0@dpg-d6qu6lngi27c73aaabdg-a.oregon-postgres.render.com/etl_seguros_0bu1")
df_curated.to_sql("F_pedidos_curated", engine, if_exists="replace", index=False)
df_rejects.to_sql("F_pedidos_rejects", engine, if_exists="replace", index=False)
print("Pedidos cargados")
# Out:
# Pedidos cargados
