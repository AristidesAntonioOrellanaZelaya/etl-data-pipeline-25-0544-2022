# %% [markdown]
# <a href="https://colab.research.google.com/github/AristidesAntonioOrellanaZelaya/etl-data-pipeline-25-0544-2022/blob/main/notebooks/F_clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/AristidesAntonioOrellanaZelaya/etl-data-pipeline-25-0544-2022/refs/heads/main/data/raw/F_clientes.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   id_cliente             cliente                  correo  telefono
# 0     CL1000     Paola Mendoza 0  cliente061@empresa.com  73372703
# 1     CL1001    Elena Ramírez 1   cliente186@outlook.com  75447071
# 2     CL1002  Valeria Martínez 2   cliente25@outlook.com  76605966
# 3     CL1003    Daniela Rivera 3    cliente317@correo.sv  73134898
# 4     CL1004     Elena Morales 4    cliente426@correo.sv  78399637

# %% [markdown]
# Limpieza de datos

# %%
df = df.drop_duplicates()
df = df.dropna()

# %% [markdown]
# Separar curated y rejects

# %%
df_rejects = df[df.isnull().any(axis=1)]
df_curated = df.dropna()
print(f"Curated: {len(df_curated)} | Rejects: {len(df_rejects)}")
# Out:
# Curated: 130 | Rejects: 0

# %% [markdown]
# Cargar a PostgreSQL

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://etl_seguros_0bu1_user:77XuQLEAFlcOXDHTkkoSKUTTmQKQe6H0@dpg-d6qu6lngi27c73aaabdg-a.oregon-postgres.render.com/etl_seguros_0bu1")
df_curated.to_sql("F_clientes_curated", engine, if_exists="replace", index=False)
df_rejects.to_sql("F_clientes_rejects", engine, if_exists="replace", index=False)
print("Clientes cargado")
# Out:
# Clientes cargado

# %% [markdown]
# Guardar curated y rejects localmente en Colab

# %%
df_curated.to_csv("F_clientes_curated.csv", index=False)
df_rejects.to_csv("F_clientes_rejects.csv", index=False)
